# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.7/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = 'The product is really Awesome'
vs.polarity_scores(text)
# Out:
# {'compound': 0.659, 'neg': 0.0, 'neu': 0.477, 'pos': 0.523}

# %%
text2 = 'Super cheap material. I would not buy even the curtains made from this synthetic. I did not even try it.'
vs.polarity_scores(text2)
# Out:
# {'compound': 0.5994, 'neg': 0.0, 'neu': 0.83, 'pos': 0.17}

# %%
text3 = 'Does not look like the dress pictured. Too short to wear as a dress, I’m 5’7” and got a large to be sure that it fit and it barely covers my bum.'
vs.polarity_scores(text3)
# Out:
# {'compound': 0.3999, 'neg': 0.059, 'neu': 0.808, 'pos': 0.134}

# %%
# Web scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np 
import os

# %%
url = 'https://inshorts.com/en/read/world'
news_data = []
news_category = url.split('/')[-1]
data = requests.get(url)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read international news in English in less that 60 words and get updated with all top news and current affairs and headlines in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/world" rel="canonical"/>
# <link href="https://inshorts.com/en/read/world" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>World News Headlines | Latest International News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/world"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/world"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="ga(" send=""> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });"> <li class="active-category ">Sports</li> </a>
# <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category selected">World</li> </a>
# <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/french-president-posts-message-for-india-in-hindi-amid-covid19-crisis-1619522147998" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankush Verma" itemprop="name"></span>
# </span>
# <span content="French President posts message for India in Hindi amid COVID-19 crisis" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619520063036_684.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619520063036_684.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/french-president-posts-message-for-india-in-hindi-amid-covid19-crisis-1619522147998" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'French%20President%20posts%20message%20for%20India%20in%20Hindi%20amid%20COVID-19%20crisis)' });" style="color:#44444d!important">
# <span itemprop="headline">French President posts message for India in Hindi amid COVID-19 crisis</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/french-president-posts-message-for-india-in-hindi-amid-covid19-crisis-1619522147998"><span class="short">short</span></a> by <span class="author">Ankush Verma</span> /
#       <span class="time" content="2021-04-27T11:15:47.000Z" itemprop="datePublished">04:45 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">In a Facebook post in Hindi, French President Emmanuel Macron wrote, "We know that India is going through a difficult phase. France and India have always remained united: we are doing all we can to help." He also said that France will send medical equipment, ventilators, liquid oxygen containers and oxygen generators to India to fight the pandemic.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/french-president-posts-message-for-india-in-hindi-amid-covid19-crisis-1619522147998"><span class="short">short</span></a> by <span class="author">Ankush Verma</span> /
#       <span class="time" content="2021-04-27T11:15:47.000Z" itemprop="dateModified">04:45 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.facebook.com/EmmanuelMacron/posts/3126860390879859?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Facebook' });" target="_blank">Facebook</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/australia-to-send-500-ventilators-1m-surgical-masks-other-supplies-to-india-1619532397280" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Sakshita Khosla" itemprop="name"></span>
# </span>
# <span content="Australia to send 500 ventilators, 1M surgical masks &amp; other supplies to India" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619530686094_578.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619530686094_578.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/australia-to-send-500-ventilators-1m-surgical-masks-other-supplies-to-india-1619532397280" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Australia%20to%20send%20500%20ventilators%2C%201M%20surgical%20masks%20%26%20other%20supplies%20to%20India)' });" style="color:#44444d!important">
# <span itemprop="headline">Australia to send 500 ventilators, 1M surgical masks &amp; other supplies to India</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/australia-to-send-500-ventilators-1m-surgical-masks-other-supplies-to-india-1619532397280"><span class="short">short</span></a> by <span class="author">Sakshita Khosla</span> /
#       <span class="time" content="2021-04-27T14:06:37.000Z" itemprop="datePublished">07:36 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The Australian government on Tuesday said it will provide emergency medical supplies to India amid a surge in coronavirus cases here. Australia said it will 'rapidly deploy' 500 non-invasive ventilators in India, with a capacity to deploy up to 3,000 ventilators. It will also send "a significant package" of personal protective equipment (PPE) including one million surgical masks.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/australia-to-send-500-ventilators-1m-surgical-masks-other-supplies-to-india-1619532397280"><span class="short">short</span></a> by <span class="author">Sakshita Khosla</span> /
#       <span class="time" content="2021-04-27T14:06:37.000Z" itemprop="dateModified">07:36 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://twitter.com/ANI/status/1387025293584474112?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'ANI' });" target="_blank">ANI</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/india-will-get-first-batch-of-russias-sputnik-v-covid19-vaccine-on-may-1-1619521952590" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Apaar Sharma" itemprop="name"></span>
# </span>
# <span content="India will get first batch of Russia's Sputnik V COVID-19 vaccine on May 1" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619519010309_673.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619519010309_673.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/india-will-get-first-batch-of-russias-sputnik-v-covid19-vaccine-on-may-1-1619521952590" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'India%20will%20get%20first%20batch%20of%20Russia's%20Sputnik%20V%20COVID-19%20vaccine%20on%20May%201)' });" style="color:#44444d!important">
# <span itemprop="headline">India will get first batch of Russia's Sputnik V COVID-19 vaccine on May 1</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/india-will-get-first-batch-of-russias-sputnik-v-covid19-vaccine-on-may-1-1619521952590"><span class="short">short</span></a> by <span class="author">Apaar Sharma</span> /
#       <span class="time" content="2021-04-27T11:12:32.000Z" itemprop="datePublished">04:42 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">India will receive the first batch of Russia's Sputnik V vaccine against COVID-19 on May 1, the head of the Russian Direct Investment Fund (RDIF), Kirill Dmitriev, has said. Russia's RDIF sovereign wealth fund, which is marketing Sputnik V globally, has signed agreements with five Indian manufacturers for over 850 million doses of the vaccine a year, Reuters reported.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/india-will-get-first-batch-of-russias-sputnik-v-covid19-vaccine-on-may-1-1619521952590"><span class="short">short</span></a> by <span class="author">Apaar Sharma</span> /
#       <span class="time" content="2021-04-27T11:12:32.000Z" itemprop="dateModified">04:42 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/business/healthcare-pharmaceuticals/india-receive-first-batch-russias-covid-19-vaccine-may-1-interfax-2021-04-26/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/pink-supermoon-seen-in-the-night-sky-across-the-world-pictures-surface-1619537784117" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Sakshita Khosla" itemprop="name"></span>
# </span>
# <span content="'Pink Supermoon' seen in the night sky across the world; pictures surface" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619536455996_940.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619536455996_940.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/pink-supermoon-seen-in-the-night-sky-across-the-world-pictures-surface-1619537784117" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': ''Pink%20Supermoon'%20seen%20in%20the%20night%20sky%20across%20the%20world%3B%20pictures%20surface)' });" style="color:#44444d!important">
# <span itemprop="headline">'Pink Supermoon' seen in the night sky across the world; pictures surface</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/pink-supermoon-seen-in-the-night-sky-across-the-world-pictures-surface-1619537784117"><span class="short">short</span></a> by <span class="author">Sakshita Khosla</span> /
#       <span class="time" content="2021-04-27T15:36:24.000Z" itemprop="datePublished">09:06 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The world witnessed the first of 2021's two supermoons on Monday (11.32 pm EDT), pictures of which have now surfaced. The full moon was termed the 'Pink Supermoon' after the North American herb creeping phlox, which is coming into its pink bloom right now. 'Supermoon' refers to either a full or a new moon at its closest point to Earth.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/pink-supermoon-seen-in-the-night-sky-across-the-world-pictures-surface-1619537784117"><span class="short">short</span></a> by <span class="author">Sakshita Khosla</span> /
#       <span class="time" content="2021-04-27T15:36:24.000Z" itemprop="dateModified">09:06 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/news/picture/pink-supermoon-dazzles-night-sky-idUSRTXBU5XX?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# <div id="div-gpt-ad-1536748319959-duhpnecb-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
# <script>
#         googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-duhpnecb-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-duhpnecb-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/hong-kong-to-reopen-bars-nightclubs-for-vaccinated-residents-1619521927626" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Athira Sasidharan" itemprop="name"></span>
# </span>
# <span content="Hong Kong to reopen bars, nightclubs for vaccinated residents" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619519179934_176.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619519179934_176.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/hong-kong-to-reopen-bars-nightclubs-for-vaccinated-residents-1619521927626" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Hong%20Kong%20to%20reopen%20bars%2C%20nightclubs%20for%20vaccinated%20residents)' });" style="color:#44444d!important">
# <span itemprop="headline">Hong Kong to reopen bars, nightclubs for vaccinated residents</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/hong-kong-to-reopen-bars-nightclubs-for-vaccinated-residents-1619521927626"><span class="short">short</span></a> by <span class="author">Athira Sasidharan</span> /
#       <span class="time" content="2021-04-27T11:12:07.000Z" itemprop="datePublished">04:42 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Hong Kong government has said that it'd ease social-distancing restrictions by allowing bars, nightclubs to reopen and operate past midnight only for vaccinated residents from Thursday. All staff and customers must have received at least one vaccine dose for the venue to be operational, it added. About 11% of the city's 7.5 million population have received their first vaccine dose. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/hong-kong-to-reopen-bars-nightclubs-for-vaccinated-residents-1619521927626"><span class="short">short</span></a> by <span class="author">Athira Sasidharan</span> /
#       <span class="time" content="2021-04-27T11:12:07.000Z" itemprop="dateModified">04:42 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.hindustantimes.com/world-news/hong-kong-to-reopen-bars-nightclubs-for-vaccinated-residents-101619513225791-amp.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Hindustan%20Times' });" target="_blank">Hindustan Times</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/who-steps-up-aid-to-india-to-stem-covid19-surge-1619537602617" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Dharini Mudgal" itemprop="name"></span>
# </span>
# <span content="WHO steps up aid to India to stem COVID-19 surge" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619534344587_203.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619534344587_203.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/who-steps-up-aid-to-india-to-stem-covid19-surge-1619537602617" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'WHO%20steps%20up%20aid%20to%20India%20to%20stem%20COVID-19%20surge)' });" style="color:#44444d!important">
# <span itemprop="headline">WHO steps up aid to India to stem COVID-19 surge</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/who-steps-up-aid-to-india-to-stem-covid19-surge-1619537602617"><span class="short">short</span></a> by <span class="author">Dharini Mudgal</span> /
#       <span class="time" content="2021-04-27T15:33:22.000Z" itemprop="datePublished">09:03 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The World Health Organization said it's stepping up efforts to help India as hospitals there struggled to cope with a huge surge in COVID-19 cases. WHO spokesman Tarik Jasarevic said, "We're working with...government to bring in essential supplies like oxygen and alleviate the immediate situation." The WHO was providing 4,000 oxygen concentrators, which only require an energy source, he added.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/who-steps-up-aid-to-india-to-stem-covid19-surge-1619537602617"><span class="short">short</span></a> by <span class="author">Dharini Mudgal</span> /
#       <span class="time" content="2021-04-27T15:33:22.000Z" itemprop="dateModified">09:03 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/world/india/rush-hospitals-big-gatherings-worsen-india-covid-crisis-who-2021-04-27/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/denmark-aims-to-start-local-production-of-covid19-vaccines-in-2022-1619528953673" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Shailesh" itemprop="name"></span>
# </span>
# <span content="Denmark aims to start local production of COVID-19 vaccines in 2022" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619527193186_596.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619527193186_596.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/denmark-aims-to-start-local-production-of-covid19-vaccines-in-2022-1619528953673" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Denmark%20aims%20to%20start%20local%20production%20of%20COVID-19%20vaccines%20in%202022)' });" style="color:#44444d!important">
# <span itemprop="headline">Denmark aims to start local production of COVID-19 vaccines in 2022</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/denmark-aims-to-start-local-production-of-covid19-vaccines-in-2022-1619528953673"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T13:09:13.000Z" itemprop="datePublished">06:39 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Denmark aims to start local production of COVID-19 vaccines in 2022, Danish PM Mette Frederiksen announced. "We would like to ensure greater security of vaccine supplies...We see vaccines as part of Denmark's overall preparedness and thus as critical infrastructure," she said. Frederiksen has previously criticised the EU's approach to ordering, approving and distributing vaccines within the bloc.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/denmark-aims-to-start-local-production-of-covid19-vaccines-in-2022-1619528953673"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T13:09:13.000Z" itemprop="dateModified">06:39 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/business/healthcare-pharmaceuticals/denmark-aims-produce-coronavirus-vaccines-2022-2021-04-27/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/some-covid19-tests-done-in-india-unreliable-aus-state-premier-1619523102206" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Shailesh" itemprop="name"></span>
# </span>
# <span content="Some COVID-19 tests done in India unreliable: Aus state Premier" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619520218115_947.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619520218115_947.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/some-covid19-tests-done-in-india-unreliable-aus-state-premier-1619523102206" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Some%20COVID-19%20tests%20done%20in%20India%20unreliable%3A%20Aus%20state%20Premier)' });" style="color:#44444d!important">
# <span itemprop="headline">Some COVID-19 tests done in India unreliable: Aus state Premier</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/some-covid19-tests-done-in-india-unreliable-aus-state-premier-1619523102206"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T11:31:42.000Z" itemprop="datePublished">05:01 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Premier of the Western Australia state Mark McGowan alleged that some of the COVID-19 tests conducted in India for returning travellers were either inaccurate or unreliable. McGowan's comments came after authorities said that four people in hotel quarantine in the state tested positive for COVID-19 following their return from India. "Our expectation is the number of...cases...will grow," he added.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/some-covid19-tests-done-in-india-unreliable-aus-state-premier-1619523102206"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T11:31:42.000Z" itemprop="dateModified">05:01 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/spain-to-send-7-tonnes-of-aid-to-india-to-help-fight-covid19-1619536230582" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Shailesh" itemprop="name"></span>
# </span>
# <span content="Spain to send 7 tonnes of aid to India to help fight COVID-19" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619532098084_5.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619532098084_5.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/spain-to-send-7-tonnes-of-aid-to-india-to-help-fight-covid19-1619536230582" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Spain%20to%20send%207%20tonnes%20of%20aid%20to%20India%20to%20help%20fight%20COVID-19)' });" style="color:#44444d!important">
# <span itemprop="headline">Spain to send 7 tonnes of aid to India to help fight COVID-19</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/spain-to-send-7-tonnes-of-aid-to-india-to-help-fight-covid19-1619536230582"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T15:10:30.000Z" itemprop="datePublished">08:40 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Spain will send over seven tonnes of medical supplies to India to help in its fight against coronavirus, Spanish Foreign Minister Arancha González Laya said on Tuesday. "Nobody will be safe until we are all safe," Laya added. India is currently facing a surge in coronavirus cases, recording over 3 lakh COVID-19 cases for six days straight.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/spain-to-send-7-tonnes-of-aid-to-india-to-help-fight-covid19-1619536230582"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T15:10:30.000Z" itemprop="dateModified">08:40 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/world/india/spain-send-7-tonnes-medical-aid-india-2021-04-27/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/brazils-senate-probes-covid19-response-of-bolsonaroled-govt-1619541379416" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# ...
# <span itemprop="headline">Denmark arrests 6 men for allegedly joining Islamic State group</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/denmark-arrests-6-men-for-allegedly-joining-islamic-state-group-1619543086275"><span class="short">short</span></a> by <span class="author">Dharini Mudgal</span> /
#       <span class="time" content="2021-04-27T17:04:46.000Z" itemprop="datePublished">10:34 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Police in Denmark said they on Tuesday have arrested six men who are suspected of joining and financing the Islamic State group in Syria. Two of those arrested, ages 29 and 30, allegedly travelled to Syria in 2014 where they were recruited by IS. Five of them are also suspected of sending money to financially support the group.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/denmark-arrests-6-men-for-allegedly-joining-islamic-state-group-1619543086275"><span class="short">short</span></a> by <span class="author">Dharini Mudgal</span> /
#       <span class="time" content="2021-04-27T17:04:46.000Z" itemprop="dateModified">10:34 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.hindustantimes.com/world-news/denmark-arrests-6-men-for-allegedly-joining-financing-islamic-state-group-101619527374935-amp.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Hindustan%20Times' });" target="_blank">Hindustan Times</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/ship-spills-oil-off-chinas-qingdao-port-after-collision-1619533139807" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Shailesh" itemprop="name"></span>
# </span>
# <span content="Ship spills oil off China's Qingdao port after collision" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619530567549_516.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619530567549_516.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/ship-spills-oil-off-chinas-qingdao-port-after-collision-1619533139807" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Ship%20spills%20oil%20off%20China's%20Qingdao%20port%20after%20collision)' });" style="color:#44444d!important">
# <span itemprop="headline">Ship spills oil off China's Qingdao port after collision</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/ship-spills-oil-off-chinas-qingdao-port-after-collision-1619533139807"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T14:18:59.000Z" itemprop="datePublished">07:48 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">A tanker spilled oil into the sea off the Chinese port city of Qingdao on Tuesday after being struck by another vessel, the officials said. "The force of the impact on the forward port side caused a breach in cargo tanks and ballast tanks," the ship's manager said. Operations to contain and clean up the spill are underway, he added.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/ship-spills-oil-off-chinas-qingdao-port-after-collision-1619533139807"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T14:18:59.000Z" itemprop="dateModified">07:48 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/world/china/oil-tanker-symphony-crashes-outside-chinas-qingdao-port-spills-oil-2021-04-27/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/2-spanish-journalists-killed-in-ambush-in-burkina-faso-spain-1619545285563" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Shailesh" itemprop="name"></span>
# </span>
# <span content="2 Spanish journalists killed in ambush in Burkina Faso: Spain" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619543872387_386.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/27_tue/img_1619543872387_386.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/2-spanish-journalists-killed-in-ambush-in-burkina-faso-spain-1619545285563" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': '2%20Spanish%20journalists%20killed%20in%20ambush%20in%20Burkina%20Faso%3A%20Spain)' });" style="color:#44444d!important">
# <span itemprop="headline">2 Spanish journalists killed in ambush in Burkina Faso: Spain</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/2-spanish-journalists-killed-in-ambush-in-burkina-faso-spain-1619545285563"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T17:41:25.000Z" itemprop="datePublished">11:11 pm</span> on <span clas="date">27 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Two Spanish journalists were killed after an armed ambush on an anti-poaching patrol in Burkina Faso, Spain's PM Pedro Sánchez tweeted on Tuesday. An Irish national also died, senior Burkina Faso security sources said. The attack took place in "a dangerous area where terrorists, bandits and jihadists usually operate," Spain's Foreign Minister Arancha González Laya said.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/2-spanish-journalists-killed-in-ambush-in-burkina-faso-spain-1619545285563"><span class="short">short</span></a> by <span class="author">Shailesh</span> /
#       <span class="time" content="2021-04-27T17:41:25.000Z" itemprop="dateModified">11:11 pm</span> on <span class="date">27 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.reuters.com/world/africa/three-foreigners-among-missing-after-burkina-faso-ambush-say-security-sources-2021-04-26/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">Reuters</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2021</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "aialpuio-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'world','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls = ['https://inshorts.com/en/read/world',
        'https://inshorts.com/en/read/sports',
        'https://inshorts.com/en/read/politics'
        ]

def build_dataset(urls):
  news_data = []
  for url in urls:
    news_category = url.split('/')[-1]
    data = requests.get(url)
    soup = BeautifulSoup(data.content)

    news_articles = [{'news_headline':headline.find('span', attrs={"itemprop":"headline"}).string,
                      'news_article':article.find('div', attrs={"itemprop":"articleBody"}).string,
                      'news_category':news_category}
                     
                     for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                 soup.find_all('div',class_=["news-card-content news-right-box"]))]
                     
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)
  df = df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  UP govt giving fake data to show fewer COVID-1...  ...      politics
# 56  There is no oxygen shortage in Telangana: Stat...  ...      politics
# 57  Rajasthan BJP MLAs to donate 1 month salary to...  ...      politics
# 58  Delhi managed to install only 1 oxygen plant f...  ...      politics
# 59  Future generations won't forgive you: Priyanka...  ...      politics
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv', index=False)

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
# Remove html tag
def html_tag(text):
  soup = BeautifulSoup(text, "html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2> Some important info </h2></html>')
# Out:
# ' Some important info '

# %%
# Expand Contractions
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("Y'all can't expand I'd think")
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.0.48)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.2.0)
# 'you all can not expand I would think'

# %%
import re 
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text = re.sub(pattern,'',text)
  return text

remove_sp("Wow this was fun! +- skm")
# Out:
# 'Wow this was fun  skm'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text = ' '.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords("The, and, if are all stopwords and even not")
# Out:
# 'The , , stopwords even not'

# %%
# 1. Lower case
# 2. HTML Tags
# 3. Contractions
# 4. Special Characters
# 5. Stop words

df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)

df.head()
# Out:
#                                        news_headline  ... news_category
# 0  australia send 500 ventilators 1m surgical mas...  ...         world
# 1  french president posts message india hindi ami...  ...         world
# 2  india get first batch russias sputnik v covid1...  ...         world
# 3  pink supermoon seen night sky across world pic...  ...         world
# 4  denmark aims start local production covid19 va...  ...         world
#
# [5 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df
# Out:
#                                         news_headline  ... compound
# 0   australia send 500 ventilators 1m surgical mas...  ...  -0.2023
# 1   french president posts message india hindi ami...  ...   0.1027
# 2   india get first batch russias sputnik v covid1...  ...   0.6486
# 3   pink supermoon seen night sky across world pic...  ...   0.0000
# 4   denmark aims start local production covid19 va...  ...   0.5994
# 5   pakistan deploys troops 16 cities enforce covi...  ...  -0.6124
# 6   hong kong reopen bars nightclubs vaccinated re...  ...   0.3612
# 7   ireland approves astrazeneca jj vaccines citiz...  ...   0.4588
# 8   fiji reports cases covid19 variant first detec...  ...   0.0808
# 9                  steps aid india stem covid19 surge  ...   0.7351
# 10  bangladesh approves russias sputnik v covid19 ...  ...   0.4404
# 11  taiwan stands india ready provide help prez ts...  ...   0.8074
# 12   spain send 7 tonnes aid india help fight covid19  ...   0.7783
# 13  covid19 tests done india unreliable aus state ...  ...   0.5994
# 14  brazils senate probes covid19 response bolsona...  ...  -0.5859
# 15  sri lankan cabinet approves proposal ban burqa...  ...   0.2960
# 16       redress mistake china japan diplomacy report  ...  -0.1280
# 17  denmark arrests 6 men allegedly joining islami...  ...  -0.7430
# 18      ship spills oil chinas qingdao port collision  ...   0.1779
# 19  2 spanish journalists killed ambush burkina fa...  ...  -0.9517
# 20  ipls livelihood helps thousands part ecosystem...  ...  -0.0834
# 21   mishra mistakenly applies saliva ball 1st warned  ...  -0.6369
# 22  ipl carry joy brings billions every evening im...  ...  -0.6597
# 23  dhoni heard saying not speak hindi stump mic v...  ...   0.3400
# 24  ipl coo writes letter players 5 cricketers pul...  ...   0.9287
# 25  ensure reach home seamlessly bcci foreign play...  ...   0.6705
# 26  brett lee donates 1 bitcoin help oxygen suppli...  ...   0.2585
# 27  rahul bose lauds kkrs cummins donating 50000 o...  ...   0.7579
# 28      not think rcb play dan christian vs dc aakash  ...   0.7009
# 29              time car convoy bubble danny morrison  ...  -0.5574
# 30  failed execution harshal 37run jointworst ipl ...  ...   0.2732
# 31  rishabh pant maybe improved batsman india bria...  ...   0.8246
# 32   virat kohli de villiers coaches rcb coach katich  ...   0.6656
# 33  play brand cricket gives people respite mccull...  ...   0.8785
# 34  not play best games vs mi srh dc assistant coa...  ...   0.8688
# 35               ipl continue long not disturb morgan  ...  -0.0191
# 36  gill struggling case tripathi open narine gava...  ...   0.6249
# 37  nfl player convert entire 2021 salary 920000 b...  ...   0.0000
# 38   aussies playing ipl return australia pm morrison  ...  -0.4588
# 39      olympics goal really long time sailor kumanan  ...   0.7430
# 40   ec bans victory processions counting votes may 2  ...  -0.4588
# 41  bjp govt lying availability oxygen akhilesh yadav  ...  -0.2263
# 42  covid19 negative report must officials countin...  ...   0.3178
# 43  welcome ecs decision ban poll victory processi...  ...  -0.1027
# 44  set maharashtra fire control force ncps supriy...  ...  -0.7964
# 45  covid19 deputy cm dinesh sharma hospitalised l...  ...   0.8316
# 46  healthcare system collapsed goa govt clueless ...  ...  -0.8860
# 47          type covid19 crisis not play data khattar  ...  -0.5511
# 48  pm modi govt obsessed elections rather governa...  ...  -0.1901
# 49  mamata not attend pms covid review meets due e...  ...   0.6968
# 50  head constable poll duty dies due low oxygen l...  ...  -0.7717
# 51  haasan condemns decision reopen sterlite plant...  ...  -0.6692
# 52  deliver pending remdesivir tocilizumab raj min...  ...  -0.2500
# 53  gangsterturnedpolitician mukhtar ansari tests ...  ...   0.7003
# 54  madras hc asks tn puducherry consider lockdown...  ...   0.2263
# 55  govt giving fake data show fewer covid19 death...  ...  -0.4526
# 56  no oxygen shortage telangana state health mini...  ...  -0.2406
# 57  rajasthan bjp mlas donate 1 month salary cm fu...  ...   0.4939
# 58  delhi managed install 1 oxygen plant pm fund g...  ...  -0.2023
# 59  future generations not forgive priyanka cm cov...  ...  -0.8407
#
# [60 rows x 4 columns]
